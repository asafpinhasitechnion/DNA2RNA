# %%
from Utils import *

# %%
input_folder = r"C:\Users\KerenYlab.MEDICINE\OneDrive - Technion\Asaf\DNA2RNA_ML\Output"
df = pd.read_csv(os.path.join(input_folder, 'Numerical_input.csv'), index_col=0)
cancer_types = list(df['Cancer_type'].unique())
_, expression_counts_df = read_expression_data(r'C:\Users\KerenYlab.MEDICINE\OneDrive - Technion\Asaf\Data\RNA\TCGA\Xena\tcga_xena_data', cancer_types, 'Cancer_type', mean = False)
# Out:
# BLCA
# COAD
# HNSC
# LUAD
# PAAD
# SKCM
# STAD

# %%
expression_counts_df
# Out:
# Ensembl_ID       TSPAN6  TNMD  DPM1  SCYL3  C1orf112   FGR    CFH  FUCA2  \
# BLCA-CU-A3KJ-TP    3679     0  4190    850      1195   352   2623   4621
# BLCA-K4-A3WU-TP   28986    21  2917   1909      1494   905   3848   3907
# BLCA-DK-A3IU-TP     951     1  2976    705       655  2282   2994   4011
# BLCA-GV-A40G-TP   12696     3  3564   1048       447   243    116   6068
# BLCA-DK-A3IN-TP    5760     0  1440    746      1368   412   1772   4166
# ...                 ...   ...   ...    ...       ...   ...    ...    ...
# STAD-CG-4436-TP    8612     2  7400    875      1189  1011   1091   6844
# STAD-BR-A4CR-TP    3433     1  4327   1311      1262   146    978   3986
# STAD-3M-AB47-TP    2991     2  1952    731       233   509   9890   2343
# STAD-BR-A4QI-TP   17766     0  7275   1901       809   496   1781   5227
# STAD-CG-4440-TP     867     0  4561    985       955   480  29502   3660
#
# Ensembl_ID       GCLC   NFYA  ...  AC092910.4  AC073611.1  AC136977.1  \
# ...
